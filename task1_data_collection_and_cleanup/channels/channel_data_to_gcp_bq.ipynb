# %%
# !pip install pandas-gbq

# %%
import pandas as pd
import pandas_gbq

# %%
# Set project_id to your Google Cloud Platform project ID.
project_id = "infinite-rope-363317"

# Set table_id to the full destination table ID (including the dataset ID).
table_id = 'infinite-rope-363317.youtube_data.channels'

# %%
df = pd.read_csv('data/channel_data.csv')

# %%
df.head()
# Out:
#                  channel_id                channel_title  \
# 0  UCv7hPaqfIM06j3B1vOgSPyg         久々湊るい - Kugumi Rui -
# 1  UCaLPPBLfrL-JfjfegGRZjOg  Fundación John Langdon Down
# 2  UCHwGqmYfuj8Svbj5Wa2vROA              FamilyTreeWorld
# 3  UCa1NmBc163IvqVHVx7F5Hzg                  Martian Ark
# 4  UCTIyVweR2nmNsa2y4UMbrvw   Bullish Entertainment LLC
#
#                                          description  \
# 0                       VVorks所属　\n歌とゲームが好き ⸜♡⸝ \n\n
# 1  La Fundación John Langdon Down, A. C., es la p...
# 2                                                NaN
# 3  MARS COLONY & TERRAFORMING. \nLIFE INSURANCE A...
# 4  Music Producer Publisher  Label  Distributor  ...
#
#                       custom_url                   created_at  \
# 0                     @kugumirui   2022-09-30T16:06:06.76762Z
# 1  @fundacionjohnlangdondown5676         2016-01-22T16:57:01Z
# 2           @familytreeworld1277         2015-10-29T13:57:47Z
# ...

# %%
df.dtypes
# Out:
# channel_id            object
# channel_title         object
# description           object
# custom_url            object
# created_at            object
# thumbnail             object
# country               object
# view_count             int64
# subscriber_count       int64
# hidden_subscribers      bool
# video_count            int64
# dtype: object

# %%
df['country'] = df['country'].astype(str)

# %%
pandas_gbq.to_gbq(df, table_id, project_id=project_id)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 7810.62it/s]

# %%
df.head(20)
# Out:
#                   channel_id  \
# 0   UCv7hPaqfIM06j3B1vOgSPyg
# 1   UCaLPPBLfrL-JfjfegGRZjOg
# 2   UCHwGqmYfuj8Svbj5Wa2vROA
# 3   UCa1NmBc163IvqVHVx7F5Hzg
# 4   UCTIyVweR2nmNsa2y4UMbrvw
# 5   UCYaD6JLwopfPAUCSD6lYuAA
# 6   UC6h42-fNpHCzm2hFR6_hbdg
# 7   UCd31PdbQcoMTMwmv9Ew1-zg
# 8   UCk2HlXV-nDOjNzommmvcYPQ
# 9   UCRRPU_-o0R8XrIfyq1N3CmA
# 10  UCjTHgZY7U6pajEz61sQCHBw
# 11  UCveXLUgzXXNdK93ywub6LxA
# 12  UC1SoXhy6ERfINFzzJApTKDQ
# 13  UCBbwGIeERoVbsKu1ger4KbQ
# 14  UCKgZ2WnyIP3LKLwaN7Tyx5A
# 15  UCbZR5b7VNmfh7N2_Dk6PAIw
# 16  UCcrAw59zYOWcTmOvV7_NXAQ
# 17  UCv361SF6FKznoGPKEFG9Yhw
# 18  UCUcmL8SUu3zS64MYO2O780w
# 19  UCm5S9DiKOya8hEVVUGeXW-w
#
#                                         channel_title  \
# 0                                久々湊るい - Kugumi Rui -
# 1                         Fundación John Langdon Down
# 2                                     FamilyTreeWorld
# 3                                         Martian Ark
# 4                          Bullish Entertainment LLC
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296 entries, 0 to 1295
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   channel_id          1296 non-null   object
#  1   channel_title       1296 non-null   object
#  2   description         1138 non-null   object
#  3   custom_url          1287 non-null   object
#  4   created_at          1296 non-null   object
#  5   thumbnail           1296 non-null   object
#  6   country             938 non-null    object
#  7   view_count          1296 non-null   int64
#  8   subscriber_count    1296 non-null   int64
#  9   hidden_subscribers  1296 non-null   bool
#  10  video_count         1296 non-null   int64
# dtypes: bool(1), int64(3), object(7)
# memory usage: 102.6+ KB
