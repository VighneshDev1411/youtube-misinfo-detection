# %%
import requests
import csv
import os
import asyncio
import aiohttp
import nest_asyncio
nest_asyncio.apply()

# %%
comment_file = "5"

# %%
with open('all_video_ids.txt', 'r') as file:
    total_videos = [line.strip() for line in file]

print("Total Videos: " + str(len(total_videos)))

with open('video_ids.txt', 'r') as file:
    all_videos = [line.strip() for line in file]
print("Total Correct Videos: " + str(len(all_videos)))

with open('completed_ids.txt', 'r') as file:
    completed_videos = [line.strip() for line in file]
    
print("Completed Videos: " + str(len(completed_videos)))
# Out:
# Total Videos: 787974
# Total Correct Videos: 440772
# Completed Videos: 67009

# %%
# Videos left -  slow iterative method
# video_ids = [video_id for video_id in all_videos if video_id not in completed_videos]
# print("Left Videos: " + str(len(video_ids)))

# %%
# Videos left -  fast set difference method
video_ids = list(set(all_videos) - set(completed_videos))
print("Left Videos: " + str(len(video_ids)))
# Out:
# Left Videos: 376591

# %%
# Constants
API_KEY = "your_yt_api_key"
VIDEO_IDS = video_ids[:500]
CSV_FILE = f"comment_data/comment_data{comment_file}.csv"
COMPLETED_IDS_FILE = "completed_ids.txt"
INVALID_IDS_FILE = "invalid_video_ids.txt"
CSV_FIELDS = [
    "video_id",
    "comment_id",
    "parent_id",
    "comment_text",
    "author_name",
    "author_channel_id",
    "author_url",
    "published_at",
    "can_rate",
    "can_reply",
    "like_count",
    "reply_count",
    "is_public"
]

# %%
# Define functions
async def fetch_comments_async(video_id, session):
    base_url = "https://www.googleapis.com/youtube/v3/commentThreads"
    url = f"{base_url}?key={API_KEY}&videoId={video_id}&part=snippet,replies&maxResults=100"
    comments = []

    while url:
        try:
            response = await session.get(url)
            data = await response.json()

            if "items" not in data:
                print(f"Video ID {video_id} has no comments.")
                save_invalid_id(video_id)
                return comments

            for item in data["items"]:
                comment_thread = item.get("snippet", {})
                top_comment = comment_thread.get("topLevelComment", {}).get("snippet", {})

                comment_id = item.get("id", "")
                parent_id = ""

                comment = {
                    "video_id": video_id,
                    "comment_id": comment_id,
                    "parent_id": parent_id,
                    "comment_text": top_comment.get("textDisplay", ""),
                    "author_name": top_comment.get("authorDisplayName", ""),
                    "author_channel_id": top_comment.get("authorChannelId", {}).get("value", ""),
                    "author_url": top_comment.get("authorChannelUrl", ""),
                    "published_at": top_comment.get("publishedAt", ""),
                    "can_rate": top_comment.get("canRate", False),
                    "can_reply": comment_thread.get("canReply", False),
                    "like_count": top_comment.get("likeCount", 0),
                    "reply_count": comment_thread.get("totalReplyCount", 0),
                    "is_public": comment_thread.get("isPublic", True),
                }

                comments.append(comment)

                if not is_comment_in_memory(comment):
                    append_comment_to_memory(comment)

                if "replies" in item:
                    for reply in item["replies"]["comments"]:
                        reply_comment = {
                            "video_id": video_id,
                            "comment_id": reply.get("id", ""),
                            "parent_id": comment_id,
                            "comment_text": reply["snippet"].get("textDisplay", ""),
                            "author_name": reply["snippet"].get("authorDisplayName", ""),
                            "author_channel_id": reply["snippet"].get("authorChannelId", {}).get("value", ""),
                            "author_url": reply["snippet"].get("authorChannelUrl", ""),
                            "published_at": reply["snippet"].get("publishedAt", ""),
                            "can_rate": reply["snippet"].get("canRate", False),
                            "can_reply": False,
                            "like_count": reply["snippet"].get("likeCount", 0),
                            "reply_count": 0,
                            "is_public": reply["snippet"].get("isPublic", True),
                        }

                        comments.append(reply_comment)
                        append_comment_to_memory(reply_comment)

            if "nextPageToken" in data:
                url = f"{base_url}?key={API_KEY}&videoId={video_id}&part=snippet,replies&maxResults=100&pageToken={data['nextPageToken']}"
            else:
                url = None

        except requests.exceptions.HTTPError as err:
            print(f"An error occurred while fetching comments for video ID {video_id}: {err}")
            save_invalid_id(video_id)
            return comments

    append_comments_to_csv(comments)
    save_completed_id(video_id)
    print(f"Fetched {len(comments)} comments for video ID {video_id}")

def is_comment_in_memory(comment):
    # Check if a comment already exists in memory (set)
    return comment.get("comment_id") in comment_ids

def append_comment_to_memory(comment):
    # Append comment to the memory (set) to check for duplicates
    comment_ids.add(comment.get("comment_id"))

def append_comments_to_csv(comments):
    # Append a batch of comments to the CSV file
    with open(CSV_FILE, "a+", newline="") as file:
        writer = csv.DictWriter(file, fieldnames=CSV_FIELDS)
        for comment in comments:
            writer.writerow({
                "video_id": comment.get("video_id"),
                "comment_id": comment.get("comment_id"),
                "parent_id": comment.get("parent_id"),
                "comment_text": comment.get("comment_text"),
                "author_name": comment.get("author_name"),
                "author_channel_id": comment.get("author_channel_id"),
                "author_url": comment.get("author_url"),
                "published_at": comment.get("published_at"),
                "can_rate": comment.get("can_rate"),
                "can_reply": comment.get("can_reply"),
                "like_count": comment.get("like_count"),
                "reply_count": comment.get("reply_count"),
                "is_public": comment.get("is_public")
            })

def is_id_invalid(video_id):
    if not os.path.exists(INVALID_IDS_FILE):
        return False
    with open(INVALID_IDS_FILE, "r") as file:
        invalid_ids = file.read().splitlines()
        return video_id in invalid_ids

def is_id_completed(video_id):
    if not os.path.exists(COMPLETED_IDS_FILE):
        return False
    with open(COMPLETED_IDS_FILE, "r") as file:
        completed_ids = file.read().splitlines()
        return video_id in completed_ids

def save_invalid_id(video_id):
    with open(INVALID_IDS_FILE, "a") as file:
        file.write(f"{video_id}\n")

def save_completed_id(video_id):
    with open(COMPLETED_IDS_FILE, "a") as file:
        file.write(f"{video_id}\n")

async def main_async():
    tasks = []
    async with aiohttp.ClientSession() as session:
        for video_id in VIDEO_IDS:
            if is_id_invalid(video_id):
                # print(f"Skipping invalid video ID {video_id}.")
                continue

            if is_id_completed(video_id):
                # print(f"Skipping completed video ID {video_id}.")
                continue

            task = asyncio.ensure_future(fetch_comments_async(video_id, session))
            tasks.append(task)

        await asyncio.gather(*tasks)

    print("All comments fetched and saved.")

# %%
if __name__ == "__main__":
    # Initialize a set to store comment IDs in memory
    comment_ids = set()

    asyncio.run(main_async())
# Out:
# Video ID fZUGLGLVHoM has no comments.
# Video ID 5IUOVxJ3Vxw has no comments.
# Video ID XNcvDJDmhM4 has no comments.
# Fetched 0 comments for video ID DEujwAJZFoE
# Fetched 0 comments for video ID WowvZdZFDtY
# Fetched 0 comments for video ID PfwX64AkoMg
# Fetched 0 comments for video ID ol74emIa6zQ
# Fetched 0 comments for video ID j6Qvla4P9dM
# Video ID Wdlo3umjxLk has no comments.
# Video ID oTLdvWbe9bs has no comments.
# Fetched 0 comments for video ID IkYCzbZFgmA
# Video ID 6Sj5EaXFLS8 has no comments.
# Fetched 4 comments for video ID 8uACEIulQxU
# Fetched 24 comments for video ID qMOy6nZNF5g
# Fetched 0 comments for video ID kcblVTx2p7I
# Fetched 123 comments for video ID JHkbYvkRO-g
# Video ID oj1-jre9oF4 has no comments.
# Fetched 0 comments for video ID b8O_KWEAlSc
# Fetched 0 comments for video ID OtlIv4DwoGc
# Fetched 31 comments for video ID mylp1faJ16M
# Video ID 59TeOrPT8Mo has no comments.
# Fetched 46 comments for video ID 8IW8eUfK4r8
# Fetched 0 comments for video ID S5C6CCLOB0w
# Video ID nbXIAFfI4CI has no comments.
# Fetched 11 comments for video ID QJf_RvmELiY
# Fetched 3 comments for video ID C4L5bas_ZW0
# Fetched 51 comments for video ID Jixp8nxBL4U
# Video ID ZjZQzz5PHFA has no comments.
# Fetched 4 comments for video ID 7PKXn-Vdndo
# Video ID 2nU8M2waVkA has no comments.
# Fetched 2 comments for video ID Dr6L-wWwd30
# Fetched 55 comments for video ID x5esZDGh9yg
# Fetched 7 comments for video ID NSVlwuXhvtM
# Fetched 1 comments for video ID X__qkcQxp3A
# Fetched 0 comments for video ID WSwBoxtP_A0
# Fetched 17 comments for video ID HfGvzQYZTX4
# Fetched 1 comments for video ID fdLt-QliPh0
# Fetched 5 comments for video ID VU7XU4BKQ-w
# Fetched 34 comments for video ID fKBE3Qe3Pkg
# Fetched 0 comments for video ID NtYsE6xqlOU
# Fetched 0 comments for video ID SJFgO5kX-_M
# Video ID NyDDyT1lDhA has no comments.
# Fetched 99 comments for video ID kJj5h3LWfvg
# Fetched 0 comments for video ID bRvOvMwTSsw
# Fetched 147 comments for video ID sSx30OtQuKU
# Video ID 4Vmu3yMAlgI has no comments.
# Video ID ZuS6lawD6hs has no comments.
# Fetched 58 comments for video ID -bYSNQl4RpA
# Fetched 137 comments for video ID M2fSq8zvtaE
# Fetched 2 comments for video ID e20kO6_0jZs
# Fetched 0 comments for video ID h4v2WfsaUIs
# Fetched 71 comments for video ID jbHyZypcqE8
# Video ID xfAuSfbolfQ has no comments.
# Fetched 1 comments for video ID uCgNJkDdldc
# Video ID SJJESiJcrbw has no comments.
# Video ID JMa02Y1T4T8 has no comments.
# Fetched 127 comments for video ID V4qxfFPgqdc
# Fetched 0 comments for video ID RMOWssHa_rY
# Fetched 45 comments for video ID x4M_zGxfVQI
# Fetched 0 comments for video ID S8Pvmbc5jig
# Fetched 0 comments for video ID kuls6ZfvRDE
# Fetched 3 comments for video ID UqKhopEq_mE
# Video ID zJOu3u987o8 has no comments.
# Video ID g2TU8RSVzuE has no comments.
# Video ID aUNgWCYuCzI has no comments.
# Fetched 17 comments for video ID -Iz4pfL1wy4
# Fetched 0 comments for video ID ZANRkKmhdU8
# Fetched 56 comments for video ID BYGe2idsbN4
# Fetched 21 comments for video ID SbHDhKaCM3U
# Fetched 0 comments for video ID 1W1G5xI6fdE
# Fetched 2 comments for video ID YMQb2i35_vU
# Fetched 2167 comments for video ID H0IQBWWabuU
# Fetched 2211 comments for video ID SY74M6P5C88
# Fetched 2051 comments for video ID KFP3DnxOXD8
# Fetched 2186 comments for video ID dHKQMEFWLU4
# Fetched 2151 comments for video ID DD-VQlFLD64
# Fetched 2578 comments for video ID 3DGQZhQ2axc
# Fetched 2379 comments for video ID 7MWio3K_UuM
# Fetched 2131 comments for video ID ywN_vrqoq3g
# Fetched 2376 comments for video ID GeqR4clzso8
# Fetched 2515 comments for video ID 2h6xe4H4qBA
# Fetched 2452 comments for video ID W823c-hL9T0
# Fetched 2602 comments for video ID P2K7D-uMH2g
# Fetched 2819 comments for video ID JCGmMovLFho
# Fetched 2595 comments for video ID psWo2JR36r4
# Fetched 2809 comments for video ID oNg3Sg6Tpl4
# Fetched 2965 comments for video ID WSOvurxALCM
# Fetched 2921 comments for video ID 7DyaRNgVpas
# Fetched 3093 comments for video ID bNu8fVW7Dg8
# Fetched 3111 comments for video ID lYCaXJqjHgs
# Fetched 3294 comments for video ID 43qB9FpfCR8
# Fetched 3214 comments for video ID WMxEKlDtt_4
# Fetched 3060 comments for video ID sDYShnsI3ZU
# Fetched 3377 comments for video ID 91UdLPalTHQ
# Fetched 3470 comments for video ID nd_EYo96lmo
# Fetched 3729 comments for video ID OQ5Xdz6dvXA
# Fetched 3498 comments for video ID zIdqiwHsuI8
# Fetched 4125 comments for video ID kNrj87Q-4Yk
# Fetched 4216 comments for video ID 4Au69v9B7lg
# Fetched 4283 comments for video ID 6BFV1LNytHA
# Fetched 5583 comments for video ID KuPuXAUXZjY
# Fetched 5002 comments for video ID 5T6Fnwbtzp8
# Fetched 5173 comments for video ID 6KnnfdP0n00
# Fetched 6014 comments for video ID RAxBISWd090
# Fetched 5540 comments for video ID GaRdtDwEo7A
# Fetched 7693 comments for video ID 7JyE47-Ykjo
# Fetched 6796 comments for video ID a_lC7_lrSck
# Fetched 7841 comments for video ID wSbHCENBSyo
# Fetched 7603 comments for video ID I67cgXr6L6o
# Fetched 7357 comments for video ID yNTkoLf5x5U
# Fetched 8216 comments for video ID GtFAckFqnik
# Fetched 9292 comments for video ID nLwNQFXTEnc
# Fetched 9770 comments for video ID duesiyeKku4
# Fetched 10350 comments for video ID ZEwCRIi8e6A
# Fetched 11316 comments for video ID D-aCb9xsqTE
# Fetched 14599 comments for video ID ak9Ol6hf-Wk
# Fetched 16332 comments for video ID iv8GW1GaoIc
# Fetched 23330 comments for video ID g_a7dQXilCo
# Fetched 20440 comments for video ID ztuoUK5UXXg
# Fetched 21826 comments for video ID i2GC06euEDE
# Fetched 22662 comments for video ID fTNnwzXrVdg
# Fetched 21425 comments for video ID MNmc_XJp5rI
# Fetched 25867 comments for video ID CcNo07Xp8aQ
# Video ID LbKcHy9cav0 has no comments.
# Video ID 1u9XBhI0d9s has no comments.
# Video ID ruKY3GqBvYQ has no comments.
# Video ID PVbQrvlB_gw has no comments.
# Video ID JpUxQyLCBbk has no comments.
# Fetched 28647 comments for video ID yp2plKGFuzo
# Video ID rEQhA-JJlH0 has no comments.
# All comments fetched and saved.
